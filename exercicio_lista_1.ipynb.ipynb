# %%
## Aluno : Mateus de Aquino Marques Silva

#1) Crie um código que receba o nome do aluno, o ano de nascimento, o dia de hoje e a cidade onde mora. 
#E o programa deve retornar o nome, a idade em 2022, quantos dias faltam para o Natal (25), 
#quantos dias que faltam para a véspera de ano novo (31) e a cidade.

nome_aluno = input("Digite seu nome: ")
ano_nascimento = int(input("Digite seu ano de nascimento: "))
dia_hoje = int(input("Diga a data do dia de hoje: "))
cidade = input("Qual a cidade em que você mora? ")
print(f"\nSeu nome é : {nome_aluno} e você tem {2022-ano_nascimento} anos e mora na cidade {cidade}\n")
print(f"Faltam {25-dia_hoje} dias para o natal e {31-dia_hoje} dias para véspera de ano novo")
# Out:
# Digite seu nome: Mateus
# Digite seu ano de nascimento: 1994
# Diga o dia de hoje: 5
# Qual a cidade em que você mora? recife
#
# Seu nome é : Mateus e você tem 28 anos e mora na cidade recife
#
# Faltam 20 dias para o natal e 26 dias para véspera de ano novo

# %%
#2) Crie um código onde irá receber do usuário a nota de 5 provas realizadas (as notas variam entre 0 e 10 podendo ser um número decimal) 
#e retorne o valor da média nas provas.

nota_1 = float(input("Digite a nota da primeira prova: "))
nota_2 = float(input("Digite a nota da segunda prova: "))
nota_3 = float(input("Digite a nota da terceira prova: "))
nota_4 = float(input("Digite a nota da quarta prova: "))
nota_5 = float(input("Digite a nota da quinta prova: "))
media = (nota_1 + nota_2 + nota_3 + nota_4 + nota_5)/5

print(f"\nA média das provas foi {media}")

# %%
#3) A média ponderada funciona de forma parecida a média aritmética, as levando em consideração o peso de cada número utilizado no cálculo. 
#O objetivo do exercício será montar um código para o cálculo da média ponderada conforme a equação abaixo:


#x=(w1∗P+w2∗L+w3∗T)/(w1+w2+w3)


#Onde P é a média de 3 provas, L é a nota em relção a entrega das Listas de exercicios 
#(onde cada lista entregue conta como 1 ponto sendo um total de 10 listas) e T é a nota do Trabalho, onde w1, w2 e w3 são os respectivos pesos.
# Você deve desenvolver um código onde irá receber as notas das 3 provas (e calcular a média), irá receber quantas listas o 
#aluno entegou entre as 10 totais e receber a nota do Trabalho. Por fim para os pesos w1=0.4, w2=0.1 e w3=0.5, 
#devolva o valor da média ponderada do aluno.

nota_prova_1 = float(input("Qual foi a nota da primeira prova: "))
nota_prova_2 = float(input("Agora diga a nota da segunda prova: "))
nota_prova_3 = float(input("E agora a nota da terceira prova: "))
nota_listas = int(input("Quantas listas foram entregues? "))
nota_trabalho = float(input("Diga-nos a nota do trabalho: "))
w1 = 0.4
w2 = 0.1
w3 = 0.5
nota_p = (nota_prova_1 + nota_prova_2 + nota_prova_3)/3
media_ponderada = (nota_p*w1 + nota_listas*w2 + nota_trabalho*w3)/(w1 + w2 + w3)
print(f"A média ponderada é {media_ponderada}")
# Out:
# Qual foi a nota da primeira prova: 8
# Agora diga a nota da segunda prova: 7.5
# E agora a nota da terceira prova: 6.5
# Quantas listas foram entregues? 8
# Diga-nos a nota do trabalho: 6.5
# A média ponderada é 6.983333333333333

# %%
#4) A distância euclideana entre dois pontos é dada pela seguinte equação:

#d=(x1−x2)2+(y1−y2)2−−−−−−−−−−−−−−−−−−√ 

#Monte um código onde irá receber os valores de  x1 ,  y1 ,  x2  e  y2  em metros (podendo ser valores decimais) e 
#retorne o valor da distância euclidiana em metros também.

coord_x1 = float(input("Vamos começar com o primeiro ponto.\nQual sua coordenada x? "))
coord_y1 = float(input("Me diga também sua coordenada y. "))
coord_x2 = float(input("\nAgora no segundo ponto.\nQual sua coordenada x? " ))
coord_y2 = float(input("Qual a coordenada y do segundo ponto? "))
distancia = ((coord_x1 - coord_x2)**2 + (coord_y1-coord_y2)**2)**(0.5)

print(f"A distância entre os pontos é: {distancia}")
# Out:
# Vamos começar com o primeiro ponto.
# Qual sua coordenada x? 2
# Me diga também sua coordenada y. 6
#
# Agora no segundo ponto.
# Qual sua coordenada x? -1
# Qual a coordenada y do segundo ponto? 2
# A distância entre os pontos é:5.0

# %%
#5) O desvio padrão é uma métrica de dispersão onde avalia o espalhamento dos dados em uma determinada distribuição. 
#A equação para o cálculo do desvio padrão é dada por:

#σ=Σni=1(xi−x¯)2n−1−−−−−−−−−−−√

#Monte um código que receba 10 valores inteiros que variem entre 1 e 10, e retorne os valores da média e desvio padrão destes 10 valores. 
#Para auxiliar no desenvolvimento, siga os passos a seguir:

#Receba os 10 números inteiros;
#Calcular a média dos múmeros;
#Calcule as diferenças em relação a média ao quadrado;
#Cacule a soma das diferenças;
#Calcule o desvio padrão.

valor_1 = int(input("Vamos lá.\nDigite o primeiro dos dez valores: "))
valor_2 = int(input("Digite o segundo dos valores: "))
valor_3 = int(input("Diga agora o terceiro valor: "))
valor_4 = int(input("O quarto: "))
valor_5 = int(input("Quinto dos dez: "))
valor_6 = int(input("Diga-nos o sexto valor: "))
valor_7 = int(input("Estamos terminando.\nDigite o sétimo valor: "))
valor_8 = int(input("Qual o oitavo valor: "))
valor_9 = int(input("Digite o penúltimo valor: "))
valor_10 = int(input("Digite o último valor: "))

media = (valor_1 + valor_2 + valor_3 + valor_4 + valor_5 + valor_6 + valor_7 + valor_8 + valor_9 + valor_10)/10
dif_1 = (media - valor_1)**2
dif_2 = (media - valor_2)**2
dif_3 = (media - valor_3)**2
dif_4 = (media - valor_4)**2
dif_5 = (media - valor_5)**2
dif_6= (media - valor_6)**2
dif_7 = (media - valor_7)**2
dif_8 = (media - valor_8)**2
dif_9 = (media - valor_9)**2
dif_10 = (media - valor_10)**2

soma_dif = dif_1 + dif_2 + dif_3 + dif_4 + dif_5 + dif_6 + dif_7 + dif_8 + dif_9 + dif_10

desvio_padrao = (soma_dif/9)**0.5

print(f"\nA média da amostra é {media} \nO desvio padrão desta amostra é {desvio_padrao}")
# Out:
# Vamos lá.
# Digite o primeiro dos dez valores: 1
# Digite o segundo dos valores: 4
# Diga agora o terceiro valor: 6
# O quarto: 8
# Quinto dos dez: 10
# Diga-nos o sexto valor: 12
# Estamos terminando.
# Digite o sétimo valor: 14
# Qual o oitavo valor: 16
# Digite o penúltimo valor: 18
# Digite o último valor: 20
# A média da amostra é 10.9
# O desvio padrão desta amostra é 6.226288353960702
