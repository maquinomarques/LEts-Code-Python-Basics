# %% [markdown]
# __1)__ Desenvolva um código que recebe o valor de peso (em kgs) e a altura (em metros) de uma pessoa e devolva um print do IMC e em qual categoria de IMC ela se encontra. Para calcular deve-se utilizar a fórmula a seguir:
#
# <br>
#
# $$ IMC = \frac{peso}{(altura)^2} $$
#
# <br>
#
# E as faixas de IMC são classificadas segundo a tabela abaixo:
#
# <br>
#
# |      **IMC**      |      **Faixa**     |
# |:-----------------:|:------------------:|
# |       < 18,5      |       Subpeso      |
# | entre 18,6 e 24,9 |     Peso Ideal     |
# | entre 25,0 e 29,9 |    Acima do Peso   |
# | entre 30,0 e 34,9 |  Obesidade grau I  |
# | entre 35,0 e 39,9 |  Obesidade grau II |
# |      >= 40,0      | Obesidade grau III |

# %%
# Exemplos
# Teste 1 = peso = 130 kg e altura = 1,72 m 
# Resultado : IMC = 43,9, Obesidade grau III
# teste II = peso = 79 kg e altura = 1,69 m
# resultado: IMC = 27,6, Acima do Peso
# Não precisa se preocupar em arredondar os valores, pode trazer com todas as casas!

peso = float(input("Qual o peso do indivíduo? "))
altura = float(input("Qual a altura do indivíduo? "))
imc = peso/(altura**2)

if (imc < 18.5):
  faxa_peso = " Subpeso"
elif (imc < 24.9):
  faxa_peso = "Peso ideal"
elif (imc < 29.9):
  faxa_peso = "Acima do peso"
elif (imc < 34.9):
  faxa_peso = "Ovesidade Grau I"
elif (imc < 39.9):
  faxa_peso = "Obesidade Grau II"
else:
  faxa_peso = "Obesidade Grau III"

print(f"\nSeu imc é {imc}. Sua faxa de peso é {faxa_peso}")
# Out:
# Qual o peso do indivíduo? 79
# Qual a altura do indivíduo? 1.69
#
# Seu imc é 27.660095935016283. Sua faxa de peso é Acima do peso

# %%
#2) Desenvolva um código onde o programa irá recebe do usuário 3 números inteiros entre 1 e 30, e devolva os números em ordena 
#númerica do menor para o maior. O exercício deve ser resolvido utilizando if/else/elif.

numero_1 = int(input("Digite um número "))
numero_2 = int(input("Digite outro número "))
numero_3 = int(input("Digite mais um número "))

if (0 < numero_1 < 31) and (0 < numero_2 < 31) and (0 < numero_3 < 31):
  if (numero_1 >= numero_2) and (numero_1 >= numero_3) and (numero_2 >= numero_3):
      print(f'A ordem crescente é {numero_3} , {numero_2} e {numero_1}')
  elif (numero_1 >= numero_2) and (numero_1 >=numero_3) and (numero_3 >= numero_2):
      print(f'A ordem crescente é {numero_2} , {numero_3} e {numero_1}')
  elif (numero_2 >= numero_1) and (numero_2 >= numero_3) and (numero_1 >= numero_3):
      print(f'A ordem crescente é {numero_3} , {numero_1} e {numero_2}')
  elif (numero_2 >= numero_1) and (numero_2 >= numero_3) and (numero_3 >= numero_1):
      print(f'A ordem crescente é {numero_1} , {numero_3} e {numero_2}')
  elif (numero_3 >= numero_1) and (numero_3 >= numero_2) and (numero_1 >=numero_2):
      print(f'A ordem crescente é {numero_2} , {numero_1} e {numero_3}')
  elif (numero_3 >= numero_1) and (numero_3 >= numero_2) and (numero_2 >= numero_1):
      print(f'A ordem crescente é {numero_1} , {numero_2} e {numero_3}')

else:
  print("Valor inválido")
# Out:
# Digite um número 4
# Digite outro número 5
# Digite mais um número 6
# A ordem crescente é 4 , 5 e 6

# %% [markdown]
# __3 ao 5)__ O colégio Schmalkalden tem um dos sistemas mais rigorosos e complexos para a avaliação dos alunos, onde até os alunos tem dificuldades para entender realmente se de fato foram aprovados ou ficaram devendo alguma coisa. Para isso, você deverá desenvolver um código que auxilie os alunos a saberem se foram aprovados ou não. O programa deverá receber como input dos alunos as seguintes informações:
#
# <br>
#
# - Se o aluno é bolsista ou não?
# - Qual a nota das 4 provas bimestrais que o aluno tirou? (Aqui serão 4 inputs de notas que variam entre 0 e 10, podendo ser decimal);
# - Quantas listas de exercícios oram entregues ao longo do ano? (de um total de 20 listas no ano)
# - Qual foi a nota no trabalho anual desenvolvido pelo aluno?
# - Quantas faltas o aluno teve ao longo do ano?
#
# <br>
#
# Para calcular a média dos alunos, deve-se seguir a mesma regra do exercício da aula passada, conforme a equação abaixo:
#
# <br>
#
# $$ \bar{x} = \frac{w1*P + w2*L + w3*T}{w1 + w2 + w3}$$
#
# <br>
#
# Onde P é a média aritmética das 4 provas que o aluno fez, L vai ser a nota em relação as entregas das listas de exercícios (cada lista entregue vale 0,5 ponto) e T é a nota do trabalho. Agora, os critérios de avaliação dos alunos são conforme descrito abaixo:
#
# - __Alunos Bolsistas__:
# - Os pesos serão respectivamente $w1 = 7$, $w2 = 6$ e $w3 = 9$
# - Deve ter menos do que 5 faltas para ser aprovado, se tiver entre 5 e 10 faltas o aluno deve entregar um trabalho complementar, e por fim mais de 10 faltas reprovado diretamente
# - A média das provas tem que ser maior do 8.5 para ser aprovado, entre 6.5 e 8.5 deve fazer uma prova de recuperação e menor que 6.5, reprovado por prova;
# - As listas devem ter mais de 75% entregue para aprovado em listas, entre 10 e 15 listas o aluno deve entregar uma lista complementar, e se tiver menos que 10 listas entregues reprovado por lista;
# - A nota do trabalho deve ser maior que 6 para ser aprovado, caso contrário será reprovado por trabalho;
#
# - __Alunos Não Bolsistas__:
# - Os pesos serão respectivamente $w1 = 3$, $w2 = 8$ e $w3 = 2$
# - Deve ter menos do que 10 faltas para ser aprovado, se tiver entre 10 e 15 faltas o aluno deve entregar um trabalho complementar, e por fim mais de 15 faltas reprovado diretamente
# - A média das provas tem que ser maior do 6.5 para ser aprovado, entre 4.5 e 6.5 deve fazer uma prova de recuperação e menor que 4.5, reprovado por prova;
# - As listas devem ter mais de 50% entregue para aprovado em listas, entre 5 e 10 listas o aluno deve entregar uma lista complementar, e se tiver menos que 5 listas entregues reprovado por lista;
# - A nota do trabalho deve ser maior que 6 para ser aprovado, caso contrário será reprovado por trabalho;
#
# Então depois de todos os inputs dado pelo o aluno, o seu programa deve retornar:
# - Média das provas
# - Status da Prova (Aprovado, Prova de Recuperação ou Reprovado por Prova)
# - Status da Presença (Aprovado em Presença, Trabalho COmplementar ou Reprovado por Presença)
# - Nota das Listas
# - Status das Listas ( Aprovado, Entrega de Lista COmplementar ou Reprovado Por Lista)
# - Status do Trabalho (aprovado ou reprovado)
# - Media Final do Aluno

# %%
#3
bolsista = input("O aluno é bolsista? (s/n) ")
nota_prova_1 = float(input("Qual foi a nota da primeira prova: "))
nota_prova_2 = float(input("Agora diga a nota da segunda prova: "))
nota_prova_3 = float(input("E agora a nota da terceira prova: "))
nota_prova_4 = float(input("Me diga ainda a quarta nora: "))
nota_listas = int(input("Quantas listas foram entregues? "))
nota_trabalho = float(input("Diga-nos a nota do trabalho: "))
faltas = int(input("Quantas faltas tem o aluno? "))
media_provas = (nota_prova_1 + nota_prova_2 + nota_prova_3 + nota_prova_4)/4
if (bolsista == "s"):
  w1 = 7
  w2 = 6
  w3 = 9
  if (media_provas > 8.5):
    status_prova = "Aprovado"
  else:
    if (media_provas <6.5):
      status_prova = "Reprovado"
    else:
      status_prova = "Prova de recuperação"

  if (faltas < 5):
    status_falta = "Aprovado"
  else:
    if (faltas > 10):
      status_falta = "Reprovado"
    else:
      status_falta = "Trabalho complementar"

  if (nota_listas > 15):
    status_lista = "Aprovado"
  else:
     if (nota_listas < 10):
       status_lista = "Reprovado"
     else: 
       status_lista = "Entregar lista complementar"
            
else:
  w1 = 3
  w2 = 8
  w3 = 2
  if (media_provas > 6.5):
    status_prova = "Aprovado na prova"
  else:
    if (media_provas <4.5):
      status_prova = "Reprovado na prova"
    else:
      status_prova = "Prova de recuperação"

  if (faltas < 10):
    status_falta = "Aprovado na falta"
  else:
    if (faltas > 15):
      status_falta = "Reprovado na falta"
    else:
      status_falta = "Trabalho complementar"

  if (nota_listas > 10):
    status_lista = "Aprovado ns lista"
  else:
     if (nota_listas < 5):
       status_lista = "Reprovado na lista"
     else: 
       status_lista = "Entregar lista complementar"

if (nota_trabalho > 6):
  status_trabalho = "Aprovado no trabalho"  
else:
  status_trabalho = "Reprovado no trabalho"          

media_ponderada = (media_provas*w1 + nota_listas*w2 + nota_trabalho*w3)/(w1 + w2 + w3)

print(f'\nMedia das provas: {media_provas}\nStatus da prova: {status_prova}\nStatus presença: {status_falta}\nNota da lista: {nota_listas/2}\nStatus lista: {status_lista}\nStatus trabalho: {status_trabalho}\nMedia final:{media_ponderada}')
# Out:
# O aluno é bolsista? (s/n) s
# Qual foi a nota da primeira prova: 10
# Agora diga a nota da segunda prova: 4
# E agora a nota da terceira prova: 1
# Me diga ainda a quarta nora: 13
# Quantas listas foram entregues? 7
# Diga-nos a nota do trabalho: 9
# Quantas faltas tem o aluno? 3
#
# Media das provas: 7.0
# Status da prova: Prova de recuperação
# Status presença: Aprovado
# Nota da lista: 3.5
# Status lista: Reprovado
# Status trabalho: Reprovado no trabalho
# Media final:7.818181818181818

# %%
#5
bolsista = input("O aluno é bolsista? (s/n) ")
nota_prova_1 = float(input("Qual foi a nota da primeira prova: "))
nota_prova_2 = float(input("Agora diga a nota da segunda prova: "))
nota_prova_3 = float(input("E agora a nota da terceira prova: "))
nota_prova_4 = float(input("Me diga ainda a quarta nora: "))
nota_listas = int(input("Quantas listas foram entregues? "))
nota_trabalho = float(input("Diga-nos a nota do trabalho: "))
faltas = int(input("Quantas faltas tem o aluno? "))
media_provas = (nota_prova_1 + nota_prova_2 + nota_prova_3 + nota_prova_4)/4
if (bolsista == "s"):
  w1 = 7
  w2 = 6
  w3 = 9
  if (media_provas > 8.5):
    status_prova = "Aprovado"
  if (media_provas <= 8.5):
    if (media_provas <6.5):
      status_prova = "Reprovado"
    if (media_provas >= 6.5):
      status_prova = "Prova de recuperação"

  if (faltas < 5):
    status_falta = "Aprovado"
  if (faltas >= 5):
    if (faltas > 10):
      status_falta = "Reprovado"
    if (faltas <= 10):
      status_falta = "Trabalho complementar"

  if (nota_listas > 15):
    status_lista = "Aprovado"
  if (nota_listas <= 15):
     if (nota_listas < 10):
       status_lista = "Reprovado"
     if (nota_listas >= 10): 
       status_lista = "Entregar lista complementar"
            
if (bolsista == "n"):
  w1 = 3
  w2 = 8
  w3 = 2
  if (media_provas > 6.5):
    status_prova = "Aprovado na prova"
  if (media_provas <= 6.5):
    if (media_provas <4.5):
      status_prova = "Reprovado na prova"
    if (media_provas >= 4.5):
      status_prova = "Prova de recuperação"

  if (faltas < 10):
    status_falta = "Aprovado na falta"
  if (faltas >= 10):
    if (faltas > 15):
      status_falta = "Reprovado na falta"
    if (faltas <= 15):
      status_falta = "Trabalho complementar"

  if (nota_listas > 10):
    status_lista = "Aprovado ns lista"
  if (nota_listas <= 10):
     if (nota_listas < 5):
       status_lista = "Reprovado na lista"
     if (nota_listas >= 5):
       status_lista = "Entregar lista complementar"

if (nota_trabalho > 6):
  status_trabalho = "Aprovado no trabalho"  
if (nota_trabalho <= 6):
  status_trabalho = "Reprovado no trabalho"          

media_ponderada = (media_provas*w1 + nota_listas*w2 + nota_trabalho*w3)/(w1 + w2 + w3)

print(f'\nMedia das provas: {media_provas}\nStatus da prova: {status_prova}\nStatus presença: {status_falta}\nNota da lista: {nota_listas/2}\nStatus lista: {status_lista}\nStatus trabalho: {status_trabalho}\nMedia final:{media_ponderada}')
# Out:
# O aluno é bolsista? (s/n) s
# Qual foi a nota da primeira prova: 10
# Agora diga a nota da segunda prova: 4
# E agora a nota da terceira prova: 1
# Me diga ainda a quarta nora: 13
# Quantas listas foram entregues? 7
# Diga-nos a nota do trabalho: 9
# Quantas faltas tem o aluno? 3
#
# Media das provas: 7.0
# Status da prova: Prova de recuperação
# Status presença: Aprovado
# Nota da lista: 3.5
# Status lista: Reprovado
# Status trabalho: Reprovado no trabalho
# Media final:7.818181818181818

# %%
#4
bolsista = input("O aluno é bolsista? (s/n) ")
nota_prova_1 = float(input("Qual foi a nota da primeira prova: "))
nota_prova_2 = float(input("Agora diga a nota da segunda prova: "))
nota_prova_3 = float(input("E agora a nota da terceira prova: "))
nota_prova_4 = float(input("Me diga ainda a quarta nora: "))
nota_listas = int(input("Quantas listas foram entregues? "))
nota_trabalho = float(input("Diga-nos a nota do trabalho: "))
faltas = int(input("Quantas faltas tem o aluno? "))
media_provas = (nota_prova_1 + nota_prova_2 + nota_prova_3 + nota_prova_4)/4
if (bolsista == "s"):
  w1 = 7
  w2 = 6
  w3 = 9
  if (media_provas > 8.5):
    status_prova = "Aprovado"
  elif (media_provas < 6.5 ):
      status_prova = "Reprovado"
  else:
      status_prova = "Prova de recuperação"

  if (faltas < 5):
    status_falta = "Aprovado"
  elif (faltas > 10):
      status_falta = "Reprovado"
  else:
      status_falta = "Trabalho complementar"

  if (nota_listas > 15):
    status_lista = "Aprovado"
  elif (nota_listas < 10):
       status_lista = "Reprovado"
  else: 
       status_lista = "Entregar lista complementar"
            
else:
  w1 = 3
  w2 = 8
  w3 = 2
  if (media_provas > 6.5):
    status_prova = "Aprovado na prova"
  elif (media_provas <4.5):
      status_prova = "Reprovado na prova"
  else:
      status_prova = "Prova de recuperação"

  if (faltas < 10):
    status_falta = "Aprovado na falta"
  elif (faltas > 15):
      status_falta = "Reprovado na falta"
  else:
      status_falta = "Trabalho complementar"

  if (nota_listas > 10):
    status_lista = "Aprovado ns lista"
  elif (nota_listas < 5):
       status_lista = "Reprovado na lista"
  else: 
       status_lista = "Entregar lista complementar"

if (nota_trabalho > 6):
  status_trabalho = "Aprovado no trabalho"  
else:
  status_trabalho = "Reprovado no trabalho"          

media_ponderada = (media_provas*w1 + nota_listas*w2 + nota_trabalho*w3)/(w1 + w2 + w3)

print(f'\nMedia das provas: {media_provas}\nStatus da prova: {status_prova}\nStatus presença: {status_falta}\nNota da lista: {nota_listas/2}\nStatus lista: {status_lista}\nStatus trabalho: {status_trabalho}\nMedia final:{media_ponderada}')

# %%
#5
