# %%
#1) Faça um programa que lê uma string do teclado e a exibe invertida na tela.
#Exemplo: a string "batata" vira "atatab".

palavra = input("Digite uma palavra para ser invertrida ")
palavra_invertida = ""
for caracter in palavra[::-1]:
  palavra_invertida += caracter

print(f"A palavra \'{palavra}\' invertida é :{palavra_invertida}")
# Out:
# Digite uma palavra para ser invertrida mateus
# A palavra 'mateus' invertida é :suetam

# %%
#2) Faça um programa que pede para o usuário digitar 2 palavras. O seu programa deverá responder se elas são espelhadas uma da outra, ou seja, se ao inverter uma delas, temos a outra.
#Exemplo: as palavras "roma" e "amor" são espelhadas.

palavra_1 = input("Digite a primeira palavra a ser comparada: ")
palavra_2 = input("Digite a segunda palavra a ser comparada: ")
palavra_1_invertida = ""
for caracter in palavra_1[::-1]:
  palavra_1_invertida += caracter

if (palavra_1_invertida == palavra_2):
  resultado = "é"
else:
  resultado = "não é"

print(f"A palavra \'{palavra_1}\' {resultado} a palavra \'{palavra_2}\' invertida")
# Out:
# Digite a primeira palavra a ser comparada: mateus
# Digite a segunda palavra a ser comparada: suatem
# A palavra 'mateus' não é a palavra 'suatem' invertida

# %%
#3) Faça um programa que lê duas palavras do teclado e responde se elas são anagramas uma da outra, isto é, se podemos escrever uma delas apenas mudando a ordem das letras da outra.
#Exemplo: "ator" e "rota", "rota" e "tora", "lama" e "mala".

palavra_1 = input("Digite a primeira palavra a ser comparada: ")
palavra_2 = input("Digite a segunda palavra a ser comparada: ")

if (sorted(palavra_1) == sorted(palavra_2)):
  resultado = "são"
else:
  resultado = "não são"

print(f"As palavras \'{palavra_1}\' e \'{palavra_2}\' {resultado} anagramas")
# Out:
# Digite a primeira palavra a ser comparada: sldkfj
# Digite a segunda palavra a ser comparada: rweipo
# As palavras 'sldkfj' e 'rweipo' não são anagramas

# %%
#4)A cifra de César é uma forma rudimentar de criptografia onde todas as letras são deslocadas uma quantidade pré-determinada de vezes no alfabeto. 
#Por exemplo, a frase "Abra a porta" com 3 deslocamentos vira "Deud d sruwd". Caso os deslocamentos estourem o tamanho do alfabeto, 
#eles "dão a volta": no caso anterior, com 3 deslocamentos, se alguma palavra tivesse a letra "z", ela se tornaria "c".
#Faça um programa que pergunta para o usuário uma frase para ser criptografada e a quantidade de deslocamentos desejada. Seu programa irá mostrar a 
#mensagem cifrada na tela.
def cifra_cesar(texto, deslocamento):
  
  alfabeto = {"minusculo" : list('abcdefghijklmnopqrstuvwxyz'),
              "maiusculo" : list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")}
  txt_cifrado =""
  novo_caracter = ""
  for caracter in texto:
    if caracter in alfabeto["maiusculo"]:
      if (alfabeto["maiusculo"].index(caracter) + deslocamento  >= len(alfabeto["maiusculo"])):
        novo_caracter = alfabeto["maiusculo"][alfabeto["maiusculo"].index(caracter) + deslocamento - len(alfabeto["maiusculo"])]
      else:
        novo_caracter = alfabeto["maiusculo"][alfabeto["maiusculo"].index(caracter) + deslocamento ]
    elif caracter in alfabeto["minusculo"]:
      if (alfabeto["minusculo"].index(caracter) + deslocamento  >= len(alfabeto["minusculo"])):
        novo_caracter = alfabeto["minusculo"][alfabeto["minusculo"].index(caracter) + deslocamento - len(alfabeto["minusculo"])]
      else:
        novo_caracter = alfabeto["minusculo"][alfabeto["minusculo"].index(caracter) + deslocamento ]
    else:
      novo_caracter = caracter
    txt_cifrado += novo_caracter
  #print(novo_caracter)
  print(txt_cifrado)
  return txt_cifrado

cifra_cesar(input("Digite seu texto: "), int(input("Digite o delocamento: ")))
# Out:
# Digite seu texto: MmAaTtEeUuVvXx
# Digite o delocamento: 3
# PpDdWwHhXxYyAa
# 'PpDdWwHhXxYyAa'

# %%
# Out:
# Digite seu texto: abcABC
# Digite o delocamento: 2
# cdeCDE

# %%
# Out:
# DB.CA.Z'Yç~.db.c'.azy

# %%
# Out:
# ejhjuf brvj, p tfv"uyu",
